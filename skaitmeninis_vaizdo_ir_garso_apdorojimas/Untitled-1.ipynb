# %% [markdown]
# ### Skaitmeninis vaizdo ir garso apdorojimas
# ### Digital Image and Sound Processing
#
# Pirma paskaita: "Introduction to the course" +
# "The nature of Sound and Visual images"
#
# 2022-09-08

# %% [markdown]
# ### Live notes
# Skaidres: https://moodle.ktu.edu/mod/resource/view.php?id=33524
#
# ### Dėstytojas: Kestutis Jankauskas
#
# ### Kurso tikslas:
# Susipazinsim su skaitmeninio vaizod/garso kodavimo apdorojimo principais
# Taikymu realiame pasulyje
#
# ### xxx
# Kiekvina savaite po 1 teorine ir viena praktine paskaita
#
# ### Per teorija:
# Aptarsime tam tikrus principus, video paziesim
#
# Teorijai isigilnti kiekvianas pasirinks tema, ir pristatys tos temos koda
#
# Koda reiks rasyti patiesm, gailme naudoti matlaba/python
#
# Galime naudoti bibliotekas (Bet tda reiks paiskinti kaip jos veiks)
#
# Tikslas: Paiskinti koda nuo zemiausio lygio
#
# !!!!!! Del kalbos dar nuspresim !!!!!!!
#
# Per teorines paskaitas bus pora seminaru
#
# Taip pat aptrsime kaip rassyti ataskaita "Techinkal report"
#
# Pasirinksim savo projekta visam semestrui - demonstrosim persemstro viduri (Projektas - mini mokslinis darbas)
#
# Bus trys ginimai + dar galima du papildomus (60% egzo balo galim gauti uz jos)
#
# Egzaminas bus zodziu
# Zodziu grandine ...
#
# Pristatom koda
#
# Visi gynimai is kitu kodo
# Papildomas gynimas - is kitu kodo
#
# Gynimas vyksta savaite po pristatymo
# Gynimo metu gali patobulinti kito koda (Jeiou patobulini 10 is gynimo)
# Else bus klausimu
#
#
# ### Teorija:
# * Primos dvi savaites: Apie fizika (grsas, vaizdas)
# * Trecia: Kodavimo metodai
# * 5 - 7: Vaizdo/Garso/TV kodaviams
# * 8: seminaras - kaip ir 12 savaite bet dar tikriausie neturiesim pilno darbo
# * 9 - 11: Signalu/Graso/Vaizdu apdorojimo metodai
# * 12: Paskutinsi seminaras - Prodysim kaip sekesi projektas, nus skaidres (Bnadysim atitaikyti i magistro darba)
# * 13: Buferine paskaita: Einam svente svest xD
#
# ### Praktika:
# Temos turietu apimti visas temas (per visus studentus, studentas konkrecia tema)
#
# Pvz.: AS 5 savaite demonstroju ggarso kodavima, kiti ginasi 6 savaite.
#
# Komandu nebus!
#
# 15-16: Buferine paskaita - jeigu sufailinai gynima koki
#
# Priklausomai nuo pasirinktos temos - bus ir pristatymo laikas
#
# ### Demonstracijha ir gynimas
# Demo 1
# Gynimu bet 3
#
# ### Seminras
# Svarbu projekte:
# * Temas
# * Tikslas - ka norime isskaicioti
# * Uzdavinai - kaip skaldom uzdoti
# * Isvados - Obijektyvuis skaiciai 20%
#
# Struktura - 20%
# Scientifc Witing - 10%
# ...
#
# Negalima "Copy-paste" (pagijuoti)
#
# ### Egzxaminas
# Zodziu is teorijos
# Galime ir nelaikyri jei pzimys tinka
#
# ### Studjiu rezultatia
# * Suvokti principus kaip singlai apdorojami
# * Laiko daznio erdve
# * Kaip matematiskai apdoroti
# * Galime kurti ir implemntuoti signalu apdorojimo sprendimus

# %% [markdown]
# ### The nature of Sound and Visual images
# Skaidres: https://moodle.ktu.edu/mod/resource/view.php?id=33525
#
# #### The nature of sound
# Grasas - akutisnes/mechanies bangos kurios sklida kazkokia terpe (dujos, skystis, kieta) - Perdodma enrgija dalelemis - Garsas gasli atssipindieti - Luzti - Buti apsorbotas priklausomai nuo terpes
#
# Pvz.: Diesttyojes sneka - Mikrofonas paguanba - Garas i signala .. - VAP faials (amplitudziu reiksmes kaip mikrofono membrans buvo pasislinkus, koks buvo sliegis)
#
# Is dumenu strukturos garsas - vienmatis vektorius (Konkreciu laiko moduliu buvo mikrafono deformacija)
#
# #### Fizines charakteristimos
#
# Garsas kaip banga - matematinsi apdorojimas (sin, cos, ampiltude, daznis, pitch (storas/zemas))
#
# Violencele groje zemaiu, negu smuikas, kotrabosas dar zemiau
#
# Amplitude -garo stiprumas
#
# Faze - Dar grysim
#
# Judejimo greicio terpeja (dar grysim)
#
# Attenulatioin (Prislopimas) - Kaip energija isnyksta dauzydamis i molekules
#
# #### Bangos ilgis ir dazinsi
# Skirti aprasyti perijodiuskai kartojentems procesams aprasyti
#
# * E(t) = A sin(2 pi f t + fi)
# * A - amplitude
# * f - dazinis
# * t - laikas
# * fi - faze
#
# * f = v/A
# * A - bangos igis
# * v - greitis
#
# * f = 1/T
# * T - perijodas
#
# * A - Tv
#
# #### Amplitude
# Kai "Deformatas oras pasieke musu ausis" musu ausu mebrana suda,
# didelis sliegis - juda i vidu
# mazas - i apacia
#
# Amplitude yra logaritmine skale (matojema dB)
#
# Zmogaus ausies skalew yra logaritmine
#
# #### Daznis
# GIRDIMAS garasas 20hz to 20khz
# Irig naudojema logaritmine sakle
#
# Gitaros styga ar kito instrumento - pradeda vibroti (Formoje akustine banga) styga vibroje visu savo ilgiu, pusia ilgio ir t.t.
#
# Styga genroje:
# Bazini dazni,
# Harmoninkas
# ir papildomu overtonu del instumentu savybiu
#
# (Skirtingi garasai tarp instumentu atsirada del Overtonu/tempru/natos spalvos)
#
# #### Terpe
# Greitis ir slopimas priklauso nuo tankio. sliegio, greicio, temperaturos, akustines terpers judejimo
#
# #### Garso bangu saveika
# Jeigu du garsekalbiai generuoje identiskas ir jos buna fazeja, tada amplitude padvigubeja, jeigu puse fazes - tai isnyksta banga
#
# Skirtinbgos bangos gali sukurti nauja banga
#
# #### Laiko faktorius!!!
# Garsas - pastovus aplitudes kitimas laike
# Amplitude tesiogei su garsu nesusijusi
#
# #### Sound perception
#
# ### The nature of visuasl Image
#
# Elektro magnetine radsijecija
#
# Intesyvumas - (Wave amplitude)
# Color (Wave frequency)
#
# ZOmgus mato 380nm - 740 nm
#
# SviesoSpektras tieisne skale
#
# Zmogus turi tirs receptorius, kuris gaudo svieas
# Zmogaus idvidualus rewceprotiai - veikia logoaritmiskai, bet bendrai tiesisakai
#
# Realetytvi klausa - koks atstuams tarp dveju izoliotui tonu
# Absoliuti klausa - Galima nustatyi be konteksato
#
# DSestytjes nera girdejes apie absoliucia rega  (nes tiesine skale?)
#
# * Sviesos itensyvumas - log skale (gama korekcija)
# * Bagis ilgis tiesins
#
# #### xxx
# gam rays - eina keiaurai zmogu/gali jonizoti musu molekules
# IR - siluma
# Mikrobangos sujudina molekules daikto viduja
#
# Zemo dzanio - raudonas
# Auksto daznio -violetines (mielynos)
#
# Vaivorikstei nera rozines, nes zmogaus akyse nesuzadina rozines spalvos
# (Del sios priezasties, si spalva magenta - naudjema kaip nemaoma pc spritose)
#
# #### Objektu optines savybes
# Raudonas obejktas - atspindi viska iskyrus raudona
# Juoda objektas - sugere viska
# Baltas - atspindi viska
#
# Spindulasi gali buti sugeremi/atspindimi/lauzemi
#
# Svieso greitis vakume yra 300 000 km/s
#
# Medziagoj sviesa lietesne, nes ji daug karty yra sugerema ir ispindulojema (tas uzima laiko)
#
# #### Akis
# Zmogaus askis turis lesius, bei receptorius gale
# Zmogus turi dideli diapezona delto gad lesisi akije gali susitraukti, tasip pat galima reguliot svieso kieki paTEnkati i akis
#
# Sviesom salygom zmogus turi 3 recptoriu tipus (spalvu skyrimui)
# Prieblandou spalvu neskiriam
#
# Ko toliau ziurim to labiau atsiplaidoje akis , nes nereikai lenkti lesio
#
# Visual Cortex - smegenu dalis kuri apdoroje rega, bei optimizoje rega
#
# aKLOJI deme - vieta kur optinis nervas, neras foto receptoriu
#
# ### Intresting facts
# Octava - atstumas tarp dvieju natu, dvigubas atstumas dazniu prassme (400hz, 800hz, 1600hz, ...)
#
# Akordas - keliu natu kompozicija (Su furia transformacija galime nustatyti natu daznius)
#
# Sunis girdi geriau (Tik virsutineio riboj)
# Siksnosparnei girdi iki 200Khz
#
# 340 m/s - iprastas garso greitis ore
# Vandeny garsas geliauje 4.4 greiciau
# Pliene - apie 5800-5960 m/s
#
# Zaibas uzkaitina ora (Impact vietoj buna virsgarsnis greitins)
#
# !!!! SNR - signal to noise ratio !!!!! - 90db SNR nesigirdi zmogui
#
#
#
# Kai mirksim, vokas nuvalo bei suderkina aki
# Miskri kas 2 - 10s (Per diena apie 30 min)
#
# Trimacio vaizdo su viena akim nematom
#
# Zmogus gan gerai mato tamsoi, nes del bijoheminiu reakciju aktyviojesi kiti receptoriai (delto reikai laiko)
#
# Akis apvercia vaizda (Del lesiu) - smegenis ji apvercia atgal
#
# Collor bild -  nes fotoreceptoriai blogai funkcionoje

# %% [markdown]
# ### Praktika: Temu pasirinkimas
# Mano tema: Sound procesing
#
# Pasiskaityti skaidres
# pasisiziurietu interneter temaas

# %%
# Task: Daleliu judejimo iliustracija (Ziurieti skaidres)
# Galbut interactive Kur paspaudus ten banga? Su prislopimu?

# Task: E(t) = A sin(2 pi f t + fi)
# Graph with sliders

# %% [markdown]
# Done:
# *
#
# To do:
# *
#
# Misc:
# *
