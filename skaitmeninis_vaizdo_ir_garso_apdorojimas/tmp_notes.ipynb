# %% [markdown]
# 2022-09-15\
# Kaunas\
# Continuos and Discreet Signal
#
# ----
#
# Aplik gamtoje esantys signaiulai yra tolidus
#
# Discretus signalas - Laiptotas signalas
#
# Before the era of digital technologies, the signal was captured in a continuous form (Analogine fotografija)
#
# Tobula alalogo kobija neegzistoje (Nes vis atsiranda papildomo triuksmo)
#
# Continuous time signal === analog signal
#
# Discrete time signal === Digital signal
#
# Tapats signalsas skirtingom raiskom - atrodo skirtingai (atsiranda triuksmas (nes info gali buti tarpe tarp quantu))
#
# Signal to noise ratio
#
# Kelent raiska triuksmo lygis, bei signal to noise ratio mazeja
#
#
# Signala reikai uzfiksoti x ir y asimis
# y - asisi (AMplitudes rezolioucija) [ data structure ] ()
# x - asisi (Laiko rezoliucija) [ Masyvas ] (Sampling rate  40kHz, kad normaliai girdietusi)
#
# 40 000 * 8
#
# https://www.quora.com/What-is-the-average-size-of-an-MP3-song
# 96kb per s
#
# Video rezoliutions:
# * fps (time)
# * spatial (4k (Horizontalios asies poikseliu kiekis))
# * color depth resoliution (24 rgb)
#
# Jeigu kodotome tesiogei tai 1secunde uzimtu 500Mb
#
# Qunatiztion - tolgys singalas i diskretu
#
# Q(x) = A|x/A+1/2|
# A - delta
#
# Triuksmo rusis:
# * Additive noise
#     * Gaussian noise
#     * Flicker noise
#     * Brownian noise
#     * Cauchy noise
# * Multiplicative noise
# * Quantization error
# * Shot noise
# * Transient noise
# * Phase noise
#
# stadart dev didesnes negu tam tikra reiksme glaime ignoroti
#
# Gaussian blur is used to eliminate noise
#
# * ADC (Analog-Digital Converter)
# * DAC (Digital-Analog Converter)
#
# Sound signal charactrersitics
# * Bandwidth or bit-rate:
#     * Depends on physical properties of a circuit in analog systems
#     * Depends on the sampling rate and device performance in digital systems
# * Sampling Rate (time resolution):
#     * Indicates how often pressure levels are measured
#     * Depends on the performance of a digital recording device
# * Bit-depth or Resolution (amplitude resolution: 16, 24, 32 bits)
# * Signal-to-Noise Ratio or SNR
# * Number of Channels
#
#
# Erdvinis garas (I viena ausisgarsas ateina skirtingu laiku negu kita ir skirtingu garsumu, greiciu)
#
# ----
#
# Analogine fotografija
#
# ----
#
# Digital image
# * Daug mazu photo sensoriu (kiekvienas sensorius vienas pikselis)
# * Panasei kaip akis
# * Nuo sviesos sukyla kiekvieno sensoriaus Capasity (Talpa)
# * Pagal fizinias savybe isaugome reiksimais
# * Spalvotems paveiksliuunmams naudojemi9 trys sensoriai su filtatris
#
# Intensyvuma akis mato logaritmiskai
#
# Gma korekcija - leidzia logoritmiskai sutvarkyti paveiklssu (Jei jos nebutu tai nematryume jodos spalvos)
# (Akis jautrsnes prie jodos spalvos)
#
# ----
#
# Vaizdo atkurimo technologijos
# * CRT - catode ray tubes
# * LCD - principas, kad "visada" sviecia, o lcd (liquid crystals blokoje)
#     * CCFL - Sunku isgautoi jouda nes visada sviecia ....
#     * LED - Gali isjungit sviesa
# * PDL - Plasma dislpay panle (Matrica su dojumis kur, davus ytmapa, jos sviecia)
# * OLED - Orgasnic Light-emitting Diode
#
# ----
#
# Visual signal characterisitcs
# *  Resolution (spatial resolution)– the size of an image matrix (1920×1080 (HDTV), 4096×2160 (4K Digital Cinema)
# * Brightness – the perception elicited by the luminance of an image
#      * Lignest labaiu butu jeigu atsispindi svies nuo objektoi (Kaip jis sugere sviesa)
# * Contrast – the difference in luminance or color
# * Saturation (colorfulness) – the amount of chrominance in an image
# * Frame rate (time resolution) – the number of frames per second (24 FPS, 30 FPS)
# * Color depth – the number of bits used for the storage of one pixel
# * Color model or color space – defines how a color of a pixel is encoded (RGB, HSL, HSV, YUV)
#
#
# Apie svieas kalbant mums idomu spalvos bei amplitudes
# * Luminece
# * Chrominece
#
# Nesodri spalva yra pika
#
# Kdl filami vis dar 30fps?
# Nes reiktu kesit daug techl;ogiju kad preitri prie 60fps (Visomenine tv veikai ant 30fps)
#
# ----
#
#
# 3D Image
# * Stereoscopic display
# * Hologramas
#     * Pasinaudojma
#         * Interferencija
#         * Difracija
#
# ----

# %% [markdown]
# Denoizing
#
# Principal kompnent analizis
#
#
# **Independent sound component analysis**
# Issikrti atkirus sekancius zmones
#
#
# Projekte svarbus mano metodo rodiklai\
# e.g. Ar gali veikti realiu laiku,  ant kiewk geras, ir t.t.\
# Is ju ir turi buti isvados\
#
# Su python
#
# # Naujumas (JHeigu yra svarbu), jeigu nera (nesvarbu)
# Ka reika padaryti susiprojektoti savo R&D ko mes siekem kokie uzdavinia kokios isvados
#
#
# # Turieti bet tris uzdavinius
# Jie turietu eiri per visa ataskaita
# baigesi 3 isvadom apie tris uzdav8inius
