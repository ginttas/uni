# %% [markdown]
# ### 2022-09-05
#
# Kompiuterinios intelektas ir sprendimu priemimas ...
#
# ### 1 paskaita
#
# Mokinsimes:
#
# Ivdas
# 1. Priziurimasis mokymas (supervised)
# 2. Npriziurimasis (Not supervised)
# 3. Sktinamasis (reinforcement)
#
# 1.
#
# * Artimiausiu kaimynu metodas
# * sprendimu medaio
#
# * Patiem relizuoti algoritmusa
# * Panudoti uzdotyje
#
# 2.
#
# .. K-means
#
# 3. MCTS
#
# ### -------------------------------------------
#
# *Gausim problema is imones
# *Reiks padryti ko geresni sprendioma
#
#
# https://moodle.ktu.edu/pluginfile.php/550610/mod_resource/content/0/Lecture_notes_1.pdf
#
#
# 5 sav (yuziemima) atsiakitymas pirmas
#
#
# !!!! Skaitinia metodai ir algoritmai!!!!
#
#
# Gogle colab ir jupiter notebook
#
#
# ### -----------------------------------------
#
# !!!! Gradijantas - Vektorius rodantis krypti kur funkcija auga
#
# Daline isvestinre
#
# ### -------------------------------
# * Kodel imamas paklaidos kvadratas vieotk modulio? Kad tolygiau kristu optimizacija
# * But why it does? Kas jeigu pakeltume 3,4 ar 5? Priklauso nuo duomenu
#
# ### -----------------------------------------
# Kaip su expsonentinem ar cos? Delto yra activacijos fujos? Taip
#
# ### ------
# Galime inkrementiskia mzinti zingsni del tikslumo ir greitumo
#
# ### Kita tema .... Duomenu analize
#
# ### Kita tema KNN
#
# ### Kita tema sprendimu medziai
#
# Kas yra entropija?
#
# Netvarkos matas - turim dv i salkass.
#
# kaip pasirinkti kintamosoius:
#
# ### Diestytoje pasiekemas per MS Teams
#
# LD1 padaryti P1, P2, P3, Data  (kas pazymieta skaidrese zaliai)

# %% [markdown]
# ### 2022-09-11
#
# ### My Notes
#
# #### Lecture_notes_1.pdf
#
# * Weak AI (narrow AI) has a narrow scope of functions, simulates human behavior, focuses on doing one task really well.
# * Strong AI (general AI) exhibits human-level intelligence.
# * Super AI (superintelligence) surpasses human intelligence and
# ability.
#
# AI -> ML -> DL
#
# To Do:
# 1. Try different polynomial functions to analyze the results
# 2. Search and select built in python functions and compare results (built in functions with manually obtained values)
# * regressionExample.ipynb
# * continuosDataExample.tsv
#
# To do:
# 1. Apply provided example on continuosDataExample.tsv dataset
# 2. Try different ANN architectures
# * gdExample.ipynb
#
# ####
