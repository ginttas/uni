# %% [markdown]
# 2022-09-14\
# Kaunas
#
# ----
#
# 1 pask. Virtuali prof. Nancy Lynch paskaita.  Trumpas įvadas į dinamines paskirstytas sistemas ir profesorės grupės išdirbti algoritmai bei jų taikymas. (2013-04-08)\
# https://www.youtube.com/watch?v=02QGAJVm6ZI
#
# Distibuted computiong Theory for Wirless Netowels and Mobile suysrtmes
#
# Dynamci distributed system from now on DDS
#
# DDS are extermly complicated
#
# Prooblems
# * Resource alocation
# * ...
#
# DDS have mobility
# Single message canb reach a lot of noides
#
# Message colision and loss (Multiple messages at the samew time)
#
# How to manasge this complexsity?
#
# Dat mangement
# Robot coordination
# etc ...
#
# # Six exampled for network algorithms
#
# Atomic memory
# VR node layers
# Meewsage colisions and ...
#
# # 1. Maintaining atomic memory in dynamic networks
# Atomic memory - Typoe of memory taht looks like centrelized shard memory\
# Participants can read and write concurently
#
# In dynamic networks it whould have conviedent to have this kind of mewmory\
# [Attiya, Bar-Noy, Dolev 95]
#
# Read-Qourums = rows, write qourums = columns
#
# RAMOB memory / algorting
#
# * Nice algorihm, but compolicated
# * Simnplify with abstraction lasyers? (Virtual Node layer)
#
# # 2 Virtual Node layers
# * Goal to simplifyu programing on mobile network by owerlaying static virtual netrwork
# * Geoquorums [Dolev, Gilbert. Lynch, Shvartsman, Welch 03]
#
# Usages: Geografixcal meesaage routing
# Data collectino
# Coordination
# Each of usage uses viortuasl nodes
#
# Virtyual air trafic contoler
#
# Remarks:
#
#
# # 3 Robot motion coordination
# Robot swarm\
# Used: for exploratin/serch and resue etc
#
# Problem: Coordiantiino
# Conectivity
# Flocking (Travekl in same dir at same spped)
# Mapping
#
# Keeping swarm connected!!!
#
# # 4. Computing in Dynamic Graph Networks
# Dynmaic Graph network - Eges can chage in each round (Nodes are fixed)
#
# Globla brodccast (n-1 time to reach each n nodes)
#
# # 5. Dealing with Message Collisions
#
# # 6. Deeling wih message uncertanty
#
# ....\
# [Bar-Yehuda, Goldreich, Itai 87]\
# ....\
# Global brodcast\
#
# # ....
#
# Relaiable local broadcast
#
#
#
# Comuniucation uncertanty
